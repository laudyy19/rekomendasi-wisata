# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

# %%
from src.data_loader import load_data
from src.preprocessing import preprocess_data
from src.feature_engineering import create_content_feature

df = load_data()

df = preprocess_data(df)

df = create_content_feature(df)

df[["Place_Name","content"]].head()
# Out:
#                           Place_Name  \
# 0                   Monumen Nasional
# 1                           Kota Tua
# 2                      Dunia Fantasi
# 3  Taman Mini Indonesia Indah (TMII)
# 4           Atlantis Water Adventure
#
#                                              content
# 0  Budaya Jakarta Monumen Nasional atau yang popu...
# 1  Budaya Jakarta Kota tua di Jakarta, yang juga ...
# 2  Taman Hiburan Jakarta Dunia Fantasi atau diseb...
# 3  Taman Hiburan Jakarta Taman Mini Indonesia Ind...
# 4  Taman Hiburan Jakarta Atlantis Water Adventure...
