# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

# %%
import src.evaluation
import importlib

importlib.reload(src.evaluation)

from src.evaluation import precision_at_k

# %%
from src.evaluation import precision_at_k
recommended = [
    "Pantai Kuta",
    "Pantai Sanur",
    "Pantai Pandawa"
]

relevant = [
    "Pantai Kuta",
    "Pantai Pandawa"
]

precision_at_k(
    recommended,
    relevant,
    k=3
)
# Out:
# 0.6666666666666666
