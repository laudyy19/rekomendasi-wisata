# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

# %%
from src.model import build_model

print(build_model.__module__)
print(build_model.__code__.co_filename)
# Out:
# src.model
# d:\kuliah\sem 4\sistem rekomendasi\rekomendasi-wisata\src\model.py

# %%
import src.model
import importlib

importlib.reload(src.model)

from src.model import build_model

# %%
result = build_model(df)

print(type(result))
print(len(result))
# Out:
# <class 'tuple'>
# 2

# %%
from src.data_loader import load_data
from src.preprocessing import preprocess_data
from src.feature_engineering import create_content_feature
from src.model import build_model
from src.model import get_recommendations

# %%
df = load_data()

df = preprocess_data(df)

df = create_content_feature(df)

cosine_sim, indices = build_model(df)

# %%
get_recommendations(
    "Monumen Nasional",
    cosine_sim,
    indices,
    df,
    5
)
# Out:
#      Place_Id                            Place_Name  \
# 43         44                Monumen Selamat Datang
# 256       257            Monumen Bandung Lautan Api
# 258       259  Monumen Perjuangan Rakyat Jawa Barat
# 427       428        Monumen Bambu Runcing Surabaya
# 380       381                    Tugu Muda Semarang
#
#                                            Description Category      City  \
# 43   Monumen Selamat Datang adalah sebuah monumen y...   Budaya   Jakarta
# 256  Monumen Bandung Lautan Api, merupakan monumen ...   Budaya   Bandung
# 258  Monumen Perjuangan Rakyat Jawa Barat (Monju) a...   Budaya   Bandung
# 427  Monumen Bambu Runcing adalah ikon pariwisata S...   Budaya  Surabaya
# 380  Tugu Muda ("Monumen Pemuda" Indonesia) adalah ...   Budaya  Semarang
#
#      Price  Rating Time_Minutes  \
# 43       0     4.7         15.0
# 256      0     4.3
# 258      0     4.5         45.0
# 427      0     4.6         15.0
# 380      0     4.7
#
#                                           Coordinate       Lat        Long  \
# 43   {'lat': -6.194997799999999, 'lng': 106.8230496} -6.194998  106.823050
# 256           {'lat': -6.9338497, 'lng': 107.604925} -6.933850  107.604925
# 258          {'lat': -6.8934327, 'lng': 107.6185513} -6.893433  107.618551
# 427  {'lat': -7.267775500000001, 'lng': 112.7443898} -7.267775  112.744390
# 380          {'lat': -6.9843485, 'lng': 110.4093207} -6.984349  110.409321
#
#                                                content  Similarity
# 43   Budaya Jakarta Monumen Selamat Datang adalah s...    0.266467
# 256  Budaya Bandung Monumen Bandung Lautan Api, mer...    0.262084
# 258  Budaya Bandung Monumen Perjuangan Rakyat Jawa ...    0.257936
# 427  Budaya Surabaya Monumen Bambu Runcing adalah i...    0.211532
# 380  Budaya Semarang Tugu Muda ("Monumen Pemuda" In...    0.186267

# %%
from src.data_loader import load_data
from src.preprocessing import preprocess_data
from src.feature_engineering import create_content_feature
from src.model import build_model

df = load_data()

df = preprocess_data(df)

df = create_content_feature(df)

cosine_sim, indices = build_model(df)

cosine_sim.shape
# Out:
# (437, 437)
